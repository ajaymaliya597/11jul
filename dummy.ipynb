# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaymaliya597/11jul/blob/main/dummy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#Q1
arr = np.arange(1,11)
print(arr.shape)
print(arr.size)
print(arr.ndim)
# Out:
# (10,)
# 10
# 1

# %%
#Q2
arr = np.arange(1,10)
print(np.zeros((3,3)))
print(np.ones((2,4)))
print(np.eye((2,4)))
print()
print()
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)

# %%
#Q1
arr = np.arange(1,11)
print()
print()
print()
print()
print()
# Out:
# (10,)
